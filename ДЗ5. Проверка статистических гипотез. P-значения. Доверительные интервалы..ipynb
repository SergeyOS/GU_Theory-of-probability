# %% [markdown]
# ### Задача 1
#
# Утверждается, что шарики для подшипников, изготовленные автоматическим станком, имеют средний диаметр 17 мм. Используя уровень значимости 0.05 и правостороннюю критическую область, проверить данную гипотезу при условии, что в выборке из 100 шариков средний диаметр оказался равным 17.5 мм, а дисперсия известна и равна 4 мм.

# %% [markdown]
# ##### 1. Формулируются нулевая и альтернативная гипотезы.
# 1) Гипотеза $H_0$: средний диаметр шарика для подшипников равен 17 мм.
# 2) $H_1$:  средний диаметр шарика для подшипников больше 17 мм.
#
# ##### 2. Задаётся некоторая функция Т от выборки
# Предполагается, что количество шариков большое, то распределение диаметра шариков является нормальным или близким к нему. Т.к. случайная величина диаметра имеет нормальное распределение, то  среднее значение повыборке $T$ будет также иметь нормальное распределение  с параметрами $a = 17$ и $\sigma = \sqrt{\dfrac{D(X)}{n}} = \sqrt {\dfrac{4}{100}} = 0.2 $
#
# ##### 3. Фиксируется уровень значимости  $\alpha$
# Согласно условию задачи $\alpha$=0.05
#
# ##### 4. Определяется критическая область $\Omega_\alpha = (t_{1 - \alpha}, \infty)$.
#
# Согласно условиям задачи будем использовать  правостороннюю критическую область  $\Omega_\alpha = (t_{1 - \alpha}, \infty)$,
# что соответсвует
# $$\left(
# a + t_{1 - \alpha, \: n - 1} \cdot \sigma
# , +\infty
# \right) = \left(
# 17 + 1.6603911559963895 \cdot 0.2
# , +\infty
# \right) = \left(17.33207823119928, +\infty
# \right).
# $$

# %% [markdown]
# ##### 5. Проводится статистический тест
#
# Т.к. значение 17.5 попало в критическую область, то гипотезу $H_0$ (средний диаметр шарика для подшипников равен 17 мм.) отвергаем.

# %% [markdown]
# ### Задача 2
#
# Известно, что генеральная совокупность распределена нормально со средним квадратическим отклонением 16. Найти доверительный интервал для оценки математического ожидания a с надежностью 0.95, если выборочное среднее равно 80, а объём равен 256.

# %% [markdown]
# ##### Решение
# Найдем доверительный интервал согласно формуле:
# $$
# P \left(
# \overline{X} - t_{1 - \alpha/2, \: n - 1} \cdot \dfrac{S}{\sqrt{n}}
# \leq M(X) \leq
# \overline{X} + t_{1 - \alpha/2, \: n - 1} \cdot \dfrac{S}{\sqrt{n}}
# \right) = 1 - \alpha.
# $$

# %% [markdown]
# где
# $\overline{X} -  = 80$,
# $S = 16$,
# $n = 256$,

# %%
from scipy import stats
import numpy as np
t = stats.t.ppf(1-0.025, 255)
print (t)
# Out:
# 1.9693105698491928

# %% [markdown]
# $t_{1 - \alpha/2, \: n - 1} = 1.9693105698491928$.
#
# Итак, доверительный интервал:

# %%
(80 - t * 16 / np.sqrt(256), 80 + t * 16 / np.sqrt(256))
# Out:
# (78.0306894301508, 81.9693105698492)

# %% [markdown]
# ### Задача 3
#
# Продавец утверждает, что средний вес пачки печенья составляет 200 г. Из партии извлечена выборка из 10 пачек. Вес каждой пачки составляет:
#
# 202, 203, 199, 197, 195, 201, 200, 204, 194, 190
#
# Известно, что их веса распределены нормально. Верно ли утверждение продавца, если учитывать, что доверительная вероятность равна 99%?
#
# ##### Решение
# Найдем доверительный интервал, чтобы проверить гипотезу, что среднее значение веса пачки 200 г.

# %%
samples = np.array([202, 203, 199, 197, 195, 201, 200, 204, 194, 190])
n = len(samples) # 10
m = samples.mean()
s = samples.std(ddof=1)
t = stats.t.ppf(1-0.005, 9)
(m - t * s / np.sqrt(n), m + t * s / np.sqrt(n))
# Out:
# (193.92322840036354, 203.07677159963646)

# %% [markdown]
# Гипотеза принимается, т.к. вес 200г. попадает в доверительный интервал (193.92322840036354, 203.07677159963646)
